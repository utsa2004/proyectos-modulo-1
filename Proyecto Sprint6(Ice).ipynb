# %% [markdown]
# # ¡Hola Oscar! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# -----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Oscar excelente trabajo completando este proyecto! Has demostrado habilidades destacables en análisis exploratorio y visualización efectiva de datos. Además, tu capacidad para formular y verificar hipótesis estadísticas fue sólida y precisa, mostrando un fuerte dominio en el análisis crítico necesario para la toma de decisiones estratégicas. En general, desarrollaste un muy buen análisis en este caso de estudio, sigue manteniendo esta combinación de habilidades técnicas, analíticas y estratégicas en tus futuros proyectos.
#
# ¡Te deseo muchos éxitos en tu próximo Sprint! 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# ------

# %% [markdown]
# <div style="background-color: #E6E6FA; padding: 10px; font-size: 30px; font-weight: bold;">
# PROYECTO PARA TIENDA ONLINE "ICE"
# </div>

# %% [markdown]
# <div style="background-color: #F0F0F0; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO PRE-INICIAL: DESCARGAR LAS LIBRERIAS
# </div>

# %%
# Descargar las librerías
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st
import math as mt

# %% [markdown]
# <div style="background-color: #F0F0F0; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO 1: CARGA DEL ARCHIVO Y ESTUDIAR LA INFORMACION
# </div>

# %%
# Carga del archivo ue contiene los datos
games = pd.read_csv("/datasets/games.csv")

# %%
# Visualización inicial de la estructura de los datos del Dataframe "games"
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# Visualización del contenido de las primeras filas de datos del dataframe "games"
games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# Verificar si existen datos con filas duplicadas en el dataframe "games"
games.duplicated().sum()
# Out:
# 0

# %%
# Verificar si existen valores ausentes en las columnas que componen el dataframe "games"
games.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo en el análisis preliminar de los datasets. Usaste correctamente las funciones `info` y `head` para revisar la estructura y el contenido de los datos, lo que te permitió realizar los ajustes necesarios.
#
# Además hiciste un buen trabajo comprobando la presencia de datos duplicados y faltantes, esto es clave para verificar la integridad del dataset y evitar sesgos o errores al momento de analizar los datos
#
# </div>

# %%
# Identificar la columna que tiene la abreviatura "TBD", que se encuentra en la columna "User_Score"
games["User_Score"].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
# Visualizar nuevamente el dataframe "games", observando una celda que contiene la abreviatura "tbd"
games.sample(10, random_state=42)
# Out:
#                                                     Name Platform  \
# 3485   London 2012: The Official Video Game of the Ol...     X360
# 5500                                      Etrian Odyssey       DS
# 16713                                   Spirits & Spells      GBA
# 9489                                RollerCoaster Tycoon       XB
# 12993                      Rhapsody: A Musical Adventure       DS
# 12749                 Men in Black The Series: Crashdown       PS
# 7270                    Samurai Jack: The Amulet of Time      GBA
# 2935                                           King Kong     2600
# 8739                                     Pressure Cooker     2600
# 2227                                                Cars       GC
#
#        Year_of_Release         Genre  NA_sales  EU_sales  JP_sales  \
# 3485            2012.0        Sports      0.07      0.44      0.00
# 5500            2007.0  Role-Playing      0.19      0.02      0.09
# ...

# %%
# Identificar que valores tiene la columna "Rating"
games["Rating"].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
# RESUMEN DE LA VISUALIZACION DE LOS DATOS

# %% [markdown]
# <div style="font-size: 16px">
# El Dataframe games cuenta con 11 columnas de datos relacionadas con información en torno a ventas realizadas en diferentes áreas del mundo. 6 columnas tienen valores ausentes, de las cuales sobresalen por la gran cantidad de valores NaN, las columnas "Year_of_Release", "Critic_Score", "User_Score" y "Rating".
#
# No existen datos con filas duplicadas.
#
# Hay dos columnas que visualizo que los datos deben de convertirse, específicamente, la columna "Year_of_Release" a "int", y la columna "User_Score" a "float".
#
# Pude visualizar que la columna "User_Score" es la que contiene celdas marcadas con la abreviatura "TBD".
#
# Finalmente, la columna "Rating", contiene información de solo letras sin significados. Ante esto, encontré en la internet, la clasificación que asigna la Junta de Clasificación de Software de Entretenimiento (Entertainment Software Rating Board) a cada letra. En la sección de preparación de datos, crearé una columna donde se muestre el significado asociado a cada letra, a fin de tener mejor contexto de los datos en el resto del proyecto.
# </div>

# %% [markdown]
# <div style="background-color: #F0F0F0; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO 2: PREPARAR LOS DATOS
# </div>

# %%
# Reemplaza los nombres de las columnas en minúsculas
games.columns = games.columns.str.lower()
games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo, es una excelente práctica convertir los nombres de las columnas a minúsculas para facilitar el trabajo posterior y evitar errores por tener una combinación de mayúsculas y minúsculas.
#
# </div>

# %%
# Eliminar las 2 filas con valores ausentes en la columna "name", por no ser representativos
games = games.dropna(subset=["name"])
games["name"].isna().sum()
# Out:
# 0

# %%
# Eliminar las 2 filas con valores ausentes en la columna "genre", por no ser representativos
ames = games.dropna(subset=["genre"])
games["genre"].isna().sum()
# Out:
# 0

# %%
# Convertir la columna "year_of_release" de tipo "float" a tipo "int"
games["year_of_release"] = pd.to_numeric(games["year_of_release"], errors="coerce")
games["year_of_release"].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
# Reemplazar la abreviatura "tbd" por NaN en la columna "user_score"
games["user_score"] = games["user_score"].replace("tbd", np.nan)
games["user_score"].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
# Convertir la columna "user_score" de tipo "object" a tipo "float"
games["user_score"] = pd.to_numeric(games["user_score"], errors="coerce")
games["user_score"].dtype
# Out:
# dtype('float64')

# %%
# Rellenar las filas con valores ausentes de la columna "rating", con la letra "U" que significa "Unknown"
games["rating"].fillna("U", inplace=True)
games["rating"].isna().sum()
# Out:
# 0

# %%
# Nueva columna con el significado de las letras de la columna "rating"

# Diccionario de mapeo
rating_map = {
    'E': 'Everyone',
    'E10+': 'Everyone 10 and older',
    'T': 'Teen',
    'M': 'Mature',
    'AO': 'Adults Only',
    'K-A': 'Kids to Adults',  # aunque es antiguo, fue reemplazado por "E" y ya no se usa oficialmente.
    'EC': 'Early Childhood',
    'U': 'Unknown',
    'RP': 'Rating Pending'
}

# Crear la nueva columna
games['rating_names'] = games['rating'].map(rating_map)

# %%
# Visualizar la actualización de la información general de los datos en el dataframe "games", para validar que se realizaron todos los cambios
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
#  11  rating_names     16713 non-null  object
# dtypes: float64(7), object(5)
# memory usage: 1.7+ MB

# %%
# Visualizar nuevamente las celdas de datos en el dataframe "games".
games.sample(10, random_state=42)
# Out:
#                                    name platform  year_of_release       genre  \
# 3486                    Madden NFL 2002       XB              NaN      Sports
# 5501        Call Of Duty 2: Big Red One       GC           2005.0     Shooter
# 16713                  Spirits & Spells      GBA           2003.0    Platform
# 9488              Heroes of the Pacific       XB           2005.0  Simulation
# 15188  Brothers in Arms: Hell's Highway       PC           2008.0     Shooter
# 12746                    Evangelion: Jo      PSP           2009.0      Action
# 7268           Hasbro Family Game Night       DS           2009.0      Puzzle
# 2936              Minecraft: Story Mode      PS4           2015.0   Adventure
# 14383            Tork: Prehistoric Punk       XB           2005.0    Platform
# 2228              Build-A-Bear Workshop       DS           2007.0  Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
# Creación de la columna "total_sales" que suma las ventas de todas las regiones
games["total_sales"] = games["na_sales"] + games["eu_sales"] + games["jp_sales"] + games["other_sales"]
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN      U
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN      U
#
#   rating_names  total_sales
# 0     Everyone        82.54
# 1      Unknown        40.24
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# El procedimiento de limpieza y transformación que aplicaste está bien estructurado y demuestra atención tanto a la calidad de los datos como a su interpretación
#
# </div>

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
# RESUMEN DE LA PREPARACION DE DATOS

# %% [markdown]
# <div style="font-size: 16px">
#
# En el análisis inicial de los datos observé que era muy importante el tratamiento de valores ausentes que había en el dataframe “games”. A continuación, explico el tratamiento que aplique a los valores ausentes en las columnas:
#
# 1)	Elimine los valores ausentes de las columnas “name” y “genre”. Al ser solo dos valores ausentes por cada columna, eliminar esas filas no tendría gran significancia en el manejo de toda la base de datos, compuesta por 16,715 filas originales.
# 2)	Para las columnas “year_of_release”, “critic_score” y “user_score”, mantuve los valores ausentes, consideré reemplazarlos con el valor de la mediana, pero evalué que este cambio puede afectar la integridad de los datos.
# 3)	Para el caso de la columna “rating” solamente reemplace las celdas con valores ausentes con la letra “U” que significa “unknown”, o, en otras palabras, que la información es desconocida en dichas celdas. Como es una columna de tipo objeto, se puede dar este tratamiento con una palabra categórica.
#
# Respecto a los motivos por el cual existen tantos valores ausentes en la base de datos, lo más común que pase en la mayoría de las veces, es que existen deficiencias en el proceso de la captura original de los datos, evidenciando limitaciones, tales como:
#
# 1)	Falta de recopilación completa en el momento del registro, lo cual puede ser una consecuencia de una pobre capacitación del personal encargado para llevar a cabo la tarea
# 2)	Fuentes de datos incompletas
# 3)	Datos no disponibles o inclusive desconocidos
# 4)	Errores humanos en la captura y procesamiento de los datos.
#
# Respecto a la abreviatura “TBD”, el primer paso que realicé fue buscar en que columna se encontraba localizada para tener una idea a que variable se relacionaba. Observé que se encontraba en la columna “user_score”, entonces entendí, que eran puntajes que estaban todavía por otorgarse, por lo tanto, lo asocie a no tener información, lo que era igual a tratar todas las filas que tenían la abreviatura “TBD” como valores ausentes (NaN), por lo que procedí a reemplazar todos las celdas “TBD” para mantener coherencia en los datos, y posteriormente, realizar la conversión de la columna “user_score” de tipo “object” a “float”.
#
# Finalmente, relacionado con la conversión de los tipos de datos en las columnas, realice los siguientes cambios:
#
# 1)	Convertí la columna “year_of_release” de tipo “float” a “int”, esto debido a que los años no tienen fracciones.
#
# 2)	La segunda columna que convertí fue “user_score” de tipo “object” a “float”. Es evidente que una variable que maneja puntuaciones no puede ser tratada como un “objeto” o “string”, y dado que visualmente, todos los valores únicos tenían decimales, la conversión lógica era pasar los datos a “float”.
#
# Como nota final, ya no realice la conversión de la columna “critic_score” de “float” a “int”, porque, aunque todos los valores únicos terminaban en .0. No considero que esto sea de mucha trascendencia e impacte en los cálculos y pruebas estadísticas posteriores.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis es muy completo y refleja un buen criterio en el tratamiento de los valores ausentes y la conversión de tipos de datos.
#
# </div>

# %% [markdown]
# <div style="background-color: #F0F0F0; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO 3: ANALISIS DE LOS DATOS
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **JUEGOS LANZADOS POR LAS DIFERENTES PLATAFORMAS EN DIFERENTES AÑOS**
# </div>

# %%
# Cuántos juegos fueron lanzados en diferentes años

# Agrupar los juegos por año de lanzamiento y contar cuántos hay en cada año
juegos_lanzados_año = games.groupby("year_of_release")["name"].count().reset_index()

# Mostrar los datos agrupados 
print(juegos_lanzados_año)

# Crear el gráfico de líneas
ax = juegos_lanzados_año.plot(kind="bar",
            x="year_of_release",
            title="Cantidad de Juegos Lanzados por Años",
            xlabel="Años",
            ylabel="Número de Juegos",
            color="purple",
            legend=False,
            rot=90,
            figsize=[10,5])
ax.grid(False)
plt.show()
# Out:
#     year_of_release  name
# 0            1980.0     9
# 1            1981.0    46
# 2            1982.0    36
# 3            1983.0    17
# 4            1984.0    14
# 5            1985.0    14
# 6            1986.0    21
# 7            1987.0    16
# 8            1988.0    15
# 9            1989.0    17
# 10           1990.0    16
# 11           1991.0    41
# 12           1992.0    43
# 13           1993.0    60
# 14           1994.0   121
# 15           1995.0   219
# 16           1996.0   263
# 17           1997.0   289
# 18           1998.0   379
# 19           1999.0   338
# 20           2000.0   350
# 21           2001.0   482
# 22           2002.0   829
# 23           2003.0   775
# 24           2004.0   762
# 25           2005.0   939
# 26           2006.0  1006
# 27           2007.0  1197
# 28           2008.0  1427
# 29           2009.0  1426
# 30           2010.0  1255
# 31           2011.0  1136
# 32           2012.0   653
# 33           2013.0   544
# ...

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS SOBRE LOS JUEGOS LANZADOS POR LAS DIFERENTES PLATAFORMAS EN DIFERENTES AÑOS**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
# La gráfica indica que el número de juegos lanzados comenzó a crecer notablemente a partir de aproximadamente 1995, sin embargo, el auge verdadero comienza a partir del año 2000. La industria de los juegos empezó a experimentar un crecimiento exponencial hasta alcanzar su pico alrededor de los años 2008 a 2009. Este notable incremento pudo haber sido impulsado por un mayor interés del mercado, avances tecnológicos y una mayor capacidad de producción.
#
# A partir de 2009, se observa un marcado declive en el número de lanzamientos ofrecidos por las plataformas, tendencia que continúa en disminución. Las posibles razones del descenso incluyen una saturación del mercado, cambios en los gustos de los consumidores —como la preferencia por juegos ofrecidos mediante streaming por internet— y modificaciones en la forma en que se lanzan y registran los videojuegos.
#
# En resumen, los datos reflejan una tendencia real de crecimiento en el número de juegos lanzados a lo largo del tiempo; sin embargo, también podrían estar afectados por cambios en la recopilación o registro de datos que introducen sesgos en ciertos períodos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis ofrece una interpretación clara y bien fundamentada de la evolución del mercado de videojuegos, conectando el aumento y posterior descenso de lanzamientos con factores tecnológicos y de consumo.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **COMPORTAMIENTO DE LAS VENTAS GLOBALES TOTALES DE LAS PLATAFORMAS A LO LARGO DE LOS AÑOS EN LA INDUSTRIA DE LOS JUEGOS**
# </div>

# %%
# Ventas Totales Globales por Plataforma

# Agrupar las principales 10 plataformas en ventas
ventas_por_plataforma = games.groupby("platform")["total_sales"].sum().reset_index().sort_values(by="total_sales", ascending=False).reset_index(drop=True).head(10)

# Mostrar los resultados
print(ventas_por_plataforma)

# Crear el gráfico de barras
ax = ventas_por_plataforma.plot(kind="bar", 
            x="platform",
            title="Plataformas con Mayores Ventas Totales Gloables",
            xlabel="Plataformas",
            ylabel="Ventas Totales Globales (Millones en USD)",
            legend=False,
            color="gold",
            rot=45,
            figsize=[10,5])
ax.grid(False)
plt.show()
# Out:
#   platform  total_sales
# 0      PS2      1255.77
# 1     X360       971.42
# 2      PS3       939.65
# 3      Wii       907.51
# 4       DS       806.12
# 5       PS       730.86
# 6      GBA       317.85
# 7      PS4       314.14
# 8      PSP       294.05
# 9       PC       259.52

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Perfecto! La gráfica muestra claramente que la PlayStation 2 lidera en ventas, seguida por la Xbox 360 y la PlayStation 3. También destacan la Wii, Nintendo DS y la primera PlayStation. Las consolas más antiguas o menos populares tienen ventas mucho menores, lo que refleja la preferencia del mercado por Sony y Microsoft.
#
# </div>

# %%
# Ventas Totales Globales por Año de las Principales 10 Plataformas

# Obtener las 10 plataformas con mayores ventas totales
ventas_por_plataforma = games.groupby("platform")["total_sales"].sum().reset_index().sort_values(by="total_sales", ascending=False).reset_index(drop=True).head(10)

# Seleccionar las top 10 plataformas en ventas
top_10_plataformas = ventas_por_plataforma["platform"]

# Filtrar los datos originales para solo esas plataformas
datos_top_10_plataformas = games[games["platform"].isin(top_10_plataformas)]

# Agrupar por año y plataforma para ver la evolución de ventas
ventas_por_año_y_plataforma = datos_top_10_plataformas.groupby(["year_of_release", "platform"])["total_sales"].sum().reset_index()

# Imorimir los resultados por años de las 10 plataformas con mayores ventas
print(ventas_por_año_y_plataforma)

# Crear el gráfico de líneas
plt.figure(figsize=(10,5))
sns.lineplot(
    data=ventas_por_año_y_plataforma,
    x="year_of_release",
    y="total_sales",
    hue="platform",
    marker="o"
)
plt.title("Ventas Totales Globales por Año de las 10 Plataformas Principales")
plt.xlabel("Año")
plt.ylabel("Ventas Totales Globales (Millones en USD)")
plt.legend(title='Plataforma')
plt.grid(False)

plt.show()
# Out:
#      year_of_release platform  total_sales
# 0             1985.0       DS         0.02
# 1             1985.0       PC         0.04
# 2             1988.0       PC         0.03
# 3             1992.0       PC         3.03
# 4             1994.0       PC        12.87
# ..               ...      ...          ...
# 112           2016.0       PC         5.25
# 113           2016.0      PS3         3.60
# 114           2016.0      PS4        69.25
# 115           2016.0      Wii         0.18
# 116           2016.0     X360         1.52
#
# [117 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# El gráfico confirma que cada generación de consolas tiene un ciclo de vida (aproximadamente 5 años) con un período de auge y una posterior caída, lo que sugiere que el éxito de un videojuego está fuertemente vinculado al momento en el que es lanzado dentro de ese ciclo.
#
# </div>

# %%
# Revisión de los Datos de Ventas Totales Globales de las 10 Plataformas Principales
tabla_ventas_plataformas = ventas_por_año_y_plataforma.pivot_table(
    index='platform',
    columns='year_of_release',
    values='total_sales',
    margins=True,
    margins_name='Total'
)
tabla_ventas_plataformas
# Out:
# year_of_release  1985.0  1988.0  1992.0  1994.0  1995.0  1996.0  1997.0  \
# platform
# DS                 0.02     NaN     NaN     NaN     NaN     NaN     NaN
# GBA                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PC                 0.04    0.03    3.03   12.87    4.22   10.58   11.27
# PS                  NaN     NaN     NaN    6.03   35.96   94.70  136.17
# PS2                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PS3                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PS4                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PSP                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Wii                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# X360                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Total              0.03    0.03    3.03    9.45   20.09   52.64   73.72
#
# year_of_release   1998.0   1999.0   2000.0  ...      2008.0      2009.0  \
# ...

# %%
# Ventas Totales Globales de las Top 10 Plataformas por Años
ventas_plataformas_años = tabla_ventas_plataformas.sum(axis=0).reset_index()
ventas_plataformas_años.columns = ["year_of_release", 'total_sales']
ventas_plataformas_años.head(26)
# Out:
#    year_of_release  total_sales
# 0           1985.0     0.090000
# 1           1988.0     0.060000
# 2           1992.0     6.060000
# 3           1994.0    28.350000
# 4           1995.0    60.270000
# 5           1996.0   157.920000
# 6           1997.0   221.160000
# 7           1998.0   259.125000
# 8           1999.0   223.905000
# 9           2000.0   175.337500
# 10          2001.0   336.275000
# 11          2002.0   368.475000
# 12          2003.0   314.862500
# 13          2004.0   389.328000
# 14          2005.0   444.640000
# 15          2006.0   558.461250
# 16          2007.0   679.398750
# 17          2008.0   767.177143
# 18          2009.0   752.937143
# 19          2010.0   674.434286
# 20          2011.0   502.571429
# 21          2012.0   315.851667
# 22          2013.0   289.680000
# 23          2014.0   233.065000
# 24          2015.0   183.703333
# 25          2016.0    95.760000

# %%
# Determinación del Período de Vida de una Plataforma en la Industria de los Juegos a partir del año 2000

# Filtrar plataformas que tengan al menos un lanzamiento en el rango 2000-2016
filtered_games = games[
    (games['year_of_release'] >= 2000) & (games['year_of_release'] <= 2016)
]

# Agrupar por plataforma en los datos filtrados
grouped_filtered = filtered_games.groupby('platform')

# Crear lista para resultados
results_filtered = []

for platform, group in grouped_filtered:
    first_year = group['year_of_release'].min()
    last_year = group['year_of_release'].max()
    duration = last_year - first_year
    results_filtered.append({
        'platform': platform,
        'first_year': first_year,
        'last_year': last_year,
        'duration': duration
    })

# Convertir a DataFrame
duration_filtered_games = pd.DataFrame(results_filtered)

# Calcular el promedio de duración en este rango filtrado
promedio_duracion_filtrado = duration_filtered_games['duration'].mean()

print(duration_filtered_games)
print(f"EL Promedio del Período de Vida de las Plataformas en el rango de años del 2000 al 2016 es de: {promedio_duracion_filtrado:.2f} años")
# Out:
#    platform  first_year  last_year  duration
# 0       3DS      2011.0     2016.0       5.0
# 1        DC      2000.0     2008.0       8.0
# 2        DS      2004.0     2013.0       9.0
# 3        GB      2000.0     2001.0       1.0
# 4       GBA      2000.0     2007.0       7.0
# 5        GC      2001.0     2007.0       6.0
# 6       N64      2000.0     2002.0       2.0
# 7        PC      2000.0     2016.0      16.0
# 8        PS      2000.0     2003.0       3.0
# 9       PS2      2000.0     2011.0      11.0
# 10      PS3      2006.0     2016.0      10.0
# 11      PS4      2013.0     2016.0       3.0
# 12      PSP      2004.0     2015.0      11.0
# 13      PSV      2011.0     2016.0       5.0
# 14       WS      2000.0     2001.0       1.0
# 15      Wii      2006.0     2016.0      10.0
# 16     WiiU      2012.0     2016.0       4.0
# 17     X360      2005.0     2016.0      11.0
# 18       XB      2000.0     2008.0       8.0
# 19     XOne      2013.0     2016.0       3.0
# ...

# %%
# Ventas Globales Totales de las plataformas con ventas del lugar 11 al 20

# Obtener las plataformas ordenadas por ventas totales
ventas_por_plataforma = games.groupby("platform")["total_sales"].sum().reset_index().sort_values(by="total_sales", ascending=False).reset_index(drop=True)

# Seleccionar las plataformas del lugar 11 al 20 (índices 10 a 19)
plataformas_11_a_20 = ventas_por_plataforma.iloc[10:20]["platform"]

# Filtrar los datos originales para esas plataformas
datos_plataformas_11_a_20 = games[games["platform"].isin(plataformas_11_a_20)]

# Agrupar por año y plataforma para ver la evolución de ventas
ventas_por_año_y_plataforma_11_a_20 = datos_plataformas_11_a_20.groupby(["year_of_release", "platform"])["total_sales"].sum().reset_index()

# Imorimir los resultados por años de las 10 plataformas con mayores ventas
print(ventas_por_año_y_plataforma_11_a_20)

# Crear el gráfico de líneas
plt.figure(figsize=(12,8))
sns.lineplot(
    data=ventas_por_año_y_plataforma_11_a_20,
    x="year_of_release",
    y="total_sales",
    hue="platform",
    marker="o"
)
plt.title("Ventas Globales Totales de Plataformas del Lugar 11 al 20")
plt.xlabel("Año")
plt.ylabel("Ventas Globales Totales (Millones en USD)")
plt.legend(title='Plataforma')
plt.grid(False)

plt.show()
# Out:
#     year_of_release platform  total_sales
# 0            1980.0     2600        11.38
# 1            1981.0     2600        35.68
# 2            1982.0     2600        28.88
# 3            1983.0     2600         5.84
# 4            1983.0      NES        10.96
# ..              ...      ...          ...
# 78           2015.0     WiiU        16.35
# 79           2015.0     XOne        60.14
# 80           2016.0      3DS        15.14
# 81           2016.0     WiiU         4.60
# 82           2016.0     XOne        26.15
#
# [83 rows x 3 columns]

# %%
# Cálculo de la Tasa de Crecimiento Anual(CAGR) de Plataformas

# Definir la Función
def calculate_cagr(start_value, end_value, periods):
    return (end_value / start_value) ** (1 / periods) - 1

# Agrupar por plataforma y obtener ventas totales por año
ventas_por_plataforma_año = games.groupby(["platform", "year_of_release"])["total_sales"].sum().reset_index()

# Para cada plataforma, calcular CAGR entre el primer y último año
cagr_list = []

for platform in ventas_por_plataforma_año['platform'].unique():
    datos = ventas_por_plataforma_año[ventas_por_plataforma_año['platform'] == platform]
    start_year = datos['year_of_release'].min()
    end_year = datos['year_of_release'].max()
    start_sales = datos[datos['year_of_release'] == start_year]['total_sales'].values[0]
    end_sales = datos[datos['year_of_release'] == end_year]['total_sales'].values[0]
    periods = end_year - start_year + 1
    cagr = calculate_cagr(start_sales, end_sales, periods)
    cagr_list.append({'platform': platform, 'CAGR': cagr})

# Convertir a DataFrame y filtrar plataformas con CAGR positivo
cagr_df = pd.DataFrame(cagr_list)
potenciales_plataformas = cagr_df[cagr_df['CAGR'] > 0].sort_values(by='CAGR', ascending=False)

print(potenciales_plataformas)
# Out:
#    platform      CAGR
# 1       3DO  1.000000
# 6       GBA  0.624791
# 18      PS4  0.277625
# 8       GEN  0.256098
# 13       PC  0.164637
# 4        DS  0.161586
# 5        GB  0.142566
# 30     XOne  0.083698

# %%
# Plataformas para Evaluar con Mejores Resultados en la Tasa de Crecimiento Anual

# Lista de plataformas para analizar
plataformas = ['3DO', 'GBA', 'GEN', 'PSV', '3DS']

# Filtrar las filas donde la plataforma esté en esa lista
games_filtrado = games[games['platform'].isin(plataformas)]

# Agrupar por plataforma y año para ver la evolución por cada plataforma
ventas_por_plataforma_y_año = games_filtrado.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

# crear gráfico de líneas
sns.set(style="white")
plt.figure(figsize=(12,8))
sns.lineplot(
    data=ventas_por_plataforma_y_año,
    x='year_of_release',
    y='total_sales',
    hue='platform',
    marker='o'
)

plt.title('Ventas Globales Totales por Año de Plataformas con mejores Resultados en Tasas de Crecimiento Anual')
plt.xlabel('Año')
plt.ylabel('Ventas Globales Totales (Millones en USD)')
plt.legend(title='Plataforma')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DEL COMPORTAMIENTO DE LAS VENTAS GLOBALES TOTALES DE LAS PLATAFORMAS A LO LARGO DE LOS AÑOS EN LA INDUSTRIA DE LOS JUEGOS**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# El análisis de las ventas de videojuegos revela que el periodo más relevante para el estudio abarca de 2000 a 2016. Si bien la plataforma PS mostró una importancia temprana al liderar las ventas de 1995 a 2000, los datos antes del nuevo milenio son limitados, con siete de las diez plataformas con mayores ventas sin información completa.
#
# **Ciclos de Vida y Dinamismo del Mercado**
#
# A partir del año 2000, un patrón claro emerge: nuevas plataformas surgen con un crecimiento meteórico, alcanzan su pico de ventas en aproximadamente dos años y luego declinan ante la entrada de nuevos competidores, repitiendo este ciclo. Este comportamiento ha sido una constante en la industria, llevando a la aparición y caídas drásticas en la ventas de múltiples líderes de la industria en su momento. Ejemplos de plataformas que dominaron y luego vieron sus ventas caer incluyen PS (1995-2000), PS2 (2000-2006), Wii (2006-2009), X360 (2010), PS3 (2011-2013). La PS4 (2014-2016), aunque aún genera ventas, ya muestra una clara disminución, lo que sugiere un ciclo de vida similar.
#
# En promedio, y tomando información entre los años 2000 al 2016, las plataformas tienen una vida útil activa de 6 a 7 años desde su lanzamiento hasta su declive. Actualmente, la PS4 es la única plataforma con ventas significativas; el resto de las plataformas que alguna vez fueron líderes ahora tienen ventas cercanas a cero, lo que subraya su irrelevancia actual y su inminente salida del mercado. Esto confirma que las plataformas más relevantes en el pasado ya no lo son, evidenciando un mercado en constante cambio con plataformas emergiendo y desapareciendo continuamente.
#
# **Desafíos en la Identificación de Plataformas Rentables**
#
# Un análisis secundario de las plataformas clasificadas del puesto 11 al 20 en ventas globales mostró el mismo patrón de nacimiento, pico y declive, sin identificar ninguna con un crecimiento continuo.
#
# Para encontrar plataformas potencialmente rentables, se evaluaron las tasas de crecimiento anual. Inicialmente, plataformas como 3DO (100%), GBA (62%), PS4 (25-28%), GEN (25-28%) y XOne (8%) parecían prometedoras. Sin embargo, un análisis más profundo de estas plataformas reveló limitaciones significativas:
#
# 3DO: Su alta tasa de crecimiento se basó en información de ventas de un solo año alrededor de 1995, haciendo los datos irrelevantes para tendencias actuales.
#
# GBA, DS y PC: Mostraron picos de ventas seguidos de declives, sin un crecimiento sostenido.
#
# GEN: Experimentó un repunte moderado en sus ventas después de un ciclo de crecimiento y declive, pero la falta de datos recientes sugiere que la plataforma pudo haber salido del mercado o se renombró.
#
# Estos hallazgos indican que la tasa de crecimiento anual no fue una métrica adecuada para identificar plataformas con potencial de rentabilidad a largo plazo en este dataset.
#
# **Conclusión sobre la Rentabilidad para 2017**
#
# Basado en el análisis de los datos históricos, no se encuentra ninguna plataforma dentro del dataframe "games" que pueda considerarse rentable para el año 2017. La situación actual del mercado de videojuegos tradicionales es desafiante, caracterizada por:
#
# Declive generalizado en las ventas de muchas plataformas.
#
# Competencia intensa que acorta los ciclos de vida de las consolas.
#
# Cambios en las preferencias del consumidor, impulsados por la aparición de nuevas tecnologías.
#
# Para identificar oportunidades potenciales para 2017 y el futuro, es crucial complementar este análisis con datos de mercado actuales, investigar nuevas tecnologías y considerar tendencias emergentes como los juegos en la nube (streaming) o la realidad virtual.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# El análisis que presentas es muy sólido y refleja una comprensión profunda del comportamiento cíclico en la industria de videojuegos, mostrando cómo las plataformas siguen patrones de auge y declive bien marcados. Lograste vincular la historia de las principales consolas con datos concretos de ventas, y supiste cuestionar la validez de ciertas métricas como la tasa de crecimiento cuando no aportaban un valor predictivo confiable.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **VENTAS GLOBALES TOTALES DE TODOS LOS JUEGOS DESGLOSADOS POR PLATAFORMAS**
# </div>

# %%
# Crea un Diagrama de Caja para Visualizar las Ventas Globales Totales de Todos los Juegos Desglosados por Plataforma

# Agrupar por plataforma y calcular estadísticas descriptivas
stats_por_plataforma = games.groupby('platform')['total_sales'].describe()

# Ordenar plataformas por mediana de ventas para mejor visualización
plataformas_ordenadas = stats_por_plataforma.sort_values('50%', ascending=False).index

# Crear el diagrama de caja y bigotes
plt.figure(figsize=(10, 5))
sns.boxplot(
    x='platform', 
    y='total_sales', 
    data=games,
    order=plataformas_ordenadas
)
plt.yscale('log')
plt.title('Distribución de Ventas Globales Totales por Plataforma')
plt.xlabel('Plataforma')
plt.ylabel('Ventas Totales')
plt.xticks(rotation=45)
plt.show()

# Calculo del valor de las medianas de las 31 plataformas para su comparación respectiba
medianas = games.groupby('platform')['total_sales'].median().sort_values(ascending=False)
print("Medianas de ventas por plataforma:\n", medianas)
# Out:
# Medianas de ventas por plataforma:
#  platform
# NES     1.375
# GB      1.165
# 2600    0.460
# SNES    0.320
# X360    0.280
# N64     0.270
# PS3     0.270
# PS      0.260
# PS2     0.230
# XOne    0.220
# WiiU    0.220
# WS      0.215
# PS4     0.200
# Wii     0.190
# GBA     0.160
# XB      0.150
# GEN     0.150
# GC      0.150
# DC      0.135
# SAT     0.120
# 3DS     0.120
# DS      0.110
# NG      0.100
# PSP     0.090
# TG16    0.080
# SCD     0.065
# PSV     0.055
# PC      0.050
# GG      0.040
# PCFX    0.030
# 3DO     0.020
# Name: total_sales, dtype: float64

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DE LAS VENTAS GLOBALES TOTALES DE TODOS LOS JUEGOS DESGLOSADOS POR PLATAFORMAS**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# El análisis de los gráficos de caja revela diferencias significativas en las ventas de juegos según la plataforma. Al ordenar las plataformas por sus medianas de ventas, se observa que “NES” ocupa la posición con mayor venta típica, seguida por otras plataformas como “GB”, “2600”, “SNES” y “X360”. La comparación entre estas métricas muestra que, aunque algunas plataformas tienen altas ventas promedio, su distribución interna varía considerablemente.
#
# Una característica destacada es la dispersión en las ventas bajas. Los bigotes inferiores largos y la presencia frecuente de valores atípicos cercanos al doble del tamaño de la caja indican una gran variabilidad en los juegos menos vendidos. Esto sugiere que, si bien muchas plataformas generan ingresos moderados o bajos en la mayoría de sus juegos, existen algunos de estos juegos que alcanzan niveles excepcionalmente altos, elevando el promedio general. La dispersión hacia abajo refleja también una amplia gama en el rendimiento de los juegos individuales.
#
# Por otro lado, se observa un sesgo hacia las ventas altas: los bigotes superiores son generalmente cortos y hay pocos valores atípicos en esa dirección. Esto implica que pocas plataformas o juegos logran ventas extraordinariamente altas, pero cuando estos casos ocurren, pueden tener un impacto significativo en el valor promedio.
#
# Un aspecto particularmente interesante surge al contrastar las plataformas con mayores ventas totales acumuladas frente a sus medianas. De las cinco principales plataformas en ventas globales totales —como “X360”, “NES”, “GB”, “2600” y otras— solo “X360” aparece en el segundo lugar en cuanto a medianas altas. Esto indica que su volumen total de ventas está concentrado en unos pocos juegos muy exitosos, lo que genera una alta dispersión en sus resultados. En contraste, plataformas como “NES”, “GB” y “2600” muestran medianas relativamente altas, sugiriendo que tuvieron un rendimiento consistente con ventas moderadas a altas durante su ciclo de vida. Sin embargo, estas plataformas probablemente fueron extremadamente rentables solo durante ciertos períodos limitados; si hubieran permanecido más tiempo en el mercado, podrían haber escalado aún más en las posiciones de ventas totales.
#
# En resumen, el análisis revela una complejidad importante: mientras algunas plataformas logran altos promedios de venta con distribuciones relativamente uniformes, otras dependen del éxito concentrado en unos pocos juegos para alcanzar sus cifras globales. La presencia significativa de valores atípicos y la dispersión interna reflejan un mercado donde tanto la consistencia como los éxitos puntuales juegan roles clave en el rendimiento total.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis de las ventas globales por plataforma logra captar muy bien las diferencias entre éxito sostenido y éxito concentrado, utilizando con precisión las herramientas visuales del diagrama de caja para interpretar la distribución y dispersión de los datos.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **EFECTO DE COMO LAS RESEÑAS DE PROFESIONALES Y USUARIOS AFECTAN LAS VENTAS DE LA PLATAFORMA PLAY STATION 3 (PS3)**
# </div>

# %%
# Crea un gráfico de Dispersión Entre las Reseñas de Profesionales y las Ventas Globales Totales de la Plataforma "Play Station 3 (PS3)

# Filtrar los datos para PS3
ps3 = games[games['platform'] == 'PS3']

# Crear gráfico de dispersión
plt.figure(figsize=(12, 8))
plt.scatter(x=ps3['critic_score'], y=ps3['total_sales'], alpha=0.5)
plt.xlabel('Reseñas de Profesionales')
plt.ylabel('Ventas Totales (Millones en USD)')
plt.title('Relación entre Reseñas de Profesionales y Ventas Globales Totales de la Plataforma de Juegos Play Station 3')
plt.grid(axis='y')

plt.show()

# %%
# Correlación entre la Reseña de Profesionales y las Ventas Globales Totales para la Plataforma Play Station 3 (PS3)

# Estimación del Coeficiciente de Correlación de la Reseña de Profesionales para la Plataforma Play Station 3 (PS3)
corr_critic = ps3['critic_score'].corr(ps3['total_sales'])
print(f'El Coeficiente de Correlación entre la Crítica de los Profesionales y las Ventas Totales en la Plataforma de Juegos Play Station 3 (PS3) es de: {corr_critic:.2f}')
# Out:
# El Coeficiente de Correlación entre la Crítica de los Profesionales y las Ventas Totales en la Plataforma de Juegos Play Station 3 (PS3) es de: 0.43

# %%
# Crea un gráfico de Dispersión Entre las Reseñas de Usuarios y las Ventas Globales Totales de la Plataforma "Play Station 3 (PS3)

# Filtrar los datos para PS3
ps3 = games[games['platform'] == 'PS3']

# Crear gráfico de dispersión
plt.figure(figsize=(12, 8))
plt.scatter(x=ps3['user_score'], y=ps3['total_sales'], alpha=0.5)
plt.xlabel('Reseñas de Usuarios')
plt.ylabel('Ventas Totales (Millones en USD)')
plt.title('Relación entre Reseñas de Usuarios y Ventas Globales Totales de la Plataforma de Juegos Play Station 3')
plt.grid(axis='y')

plt.show()

# %%
# Correlación entre la Reseña de Usuarios y las Ventas Globales Totales para la Plataforma Play Station 3 (PS3)

# Estimación del Coeficiciente de Correlación de la Reseña de Usuarios para la Plataforma Play Station 3 (PS3)
corr_user = ps3['user_score'].corr(ps3['total_sales'])
print(f'El Coeficiente de Correlación entre la Crítica de Usuarios y las Ventas Totales en la Plataforma de Juegos Play Station 3 (PS3) es de: {corr_user:.2f}')
# Out:
# El Coeficiente de Correlación entre la Crítica de Usuarios y las Ventas Totales en la Plataforma de Juegos Play Station 3 (PS3) es de: 0.13

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **CONCLUSIONES SOBRE COMO LAS RESEÑAS DE PROFESIONALES Y USUARIOS AFECTAN LAS VENTAS DE LA PLATAFORMA PLAY STATION 3 (PS3)**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Este análisis examina el impacto de las reseñas de profesionales y usuarios en las ventas totales de juegos para PlayStation 3 (PS3), basándose en gráficos de dispersión y coeficientes de correlación.
#
# **1. Reseñas de Profesionales**
#
# El análisis de las reseñas profesionales en PS3 revela una correlación moderada con las ventas (coeficiente de 0.43). Esto se evidencia en el gráfico de dispersión: los juegos con puntuaciones altas (entre 70 y 98) tienden a generar mayores ventas, mientras que aquellos con críticas bajas (30-60) registran ventas inferiores a los dos millones de dólares. Esto sugiere que una buena crítica profesional puede favorecer el éxito comercial de un juego, aunque su influencia no es extremadamente fuerte.
#
# **2. Reseñas de Usuarios**
#
# En contraste, las reseñas de los usuarios muestran una relación débil con las ventas (coeficiente de 0.13). La mayoría de los juegos se concentran en un rango de críticas de 6 a 8.3, con ventas generalmente por debajo de los 2 millones de dólares. Aunque hay menos juegos con puntuaciones extremas (muy bajas o muy altas), las calificaciones de usuario elevadas (cercanas a 10) no siempre se traducen en un incremento significativo de las ventas. Esto indica que la satisfacción del usuario, si bien influyente, no es el factor determinante principal para las ventas totales en PS3.
#
# **Conclusión**
#
# En resumen, las reseñas profesionales tienen un impacto positivo y moderado en las ventas de juegos para PS3, sugiriendo que una buena crítica puede contribuir al éxito comercial. Sin embargo, las reseñas de los usuarios muestran una relación más débil, lo que implica que otros factores —como el marketing, la popularidad de la franquicia o el reconocimiento de la marca— también influyen considerablemente en el volumen de ventas. La concentración de puntos en rangos específicos de críticas y ventas refuerza la idea de que, aunque las buenas reseñas son útiles, no garantizan por sí solas ventas elevadas.
#
# Este análisis nos ayuda a comprender que, si bien la opinión de los expertos tiene cierta relevancia en el rendimiento comercial, las perspectivas de los usuarios son solo una pieza del rompecabezas en la ecuación de ventas de los juegos de PS3.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Logras diferenciar con claridad el grado de impacto entre las críticas profesionales y las valoraciones de los usuarios, apoyándote en los coeficientes de correlación y la distribución de datos para respaldar tus conclusiones. Es particularmente útil cómo destacas la presencia de otros factores que pueden mediar la relación entre reseñas y ventas, lo que da una perspectiva más realista del comportamiento del mercado.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **COMPARATIVO DEL COMPORTAMIENTO DE LAS VENTAS DE UN JUEGO EN DIVERSAS PLATAFORMAS**
# </div>

# %%
# Compara las Ventas de los Mismos Juegos en Otras Plataformas
# Visualizar cuales son los 10 juegos con mayores ventas

# Paso 1: Obtener los 10 juegos más vendidos en todo el dataset
top_10_juegos = games.groupby('name')['total_sales'].sum().reset_index()
top_10_juegos = top_10_juegos.sort_values(by='total_sales', ascending=False).head(10)

# Lista de los nombres de estos juegos
nombres_top_juegos = top_10_juegos['name'].tolist()

# Paso 2: Filtrar los datos solo para estos juegos
juegos_filtrados = games[games['name'].isin(nombres_top_juegos)]

# Paso 3: Identificar las plataformas donde se venden estos juegos
# (opcional: si quieres solo las plataformas principales, puedes hacer un análisis adicional)
plataformas_top = juegos_filtrados['platform'].value_counts().index.tolist()

# Para este ejemplo, consideraremos todas las plataformas donde se venden estos juegos

# Paso 4: Agrupar por juego y plataforma para obtener ventas específicas
ventas_por_juego_plataforma = juegos_filtrados.groupby(['name', 'platform'])['total_sales'].sum().reset_index()

# Paso 5: Crear una tabla pivote para visualizar ventas por juego y plataforma
pivot = pd.pivot_table(
    ventas_por_juego_plataforma,
    index='name',
    columns='platform',
    values='total_sales',
    fill_value=0
)

# Agregar columna con total de ventas por juego (suma en todas plataformas)
pivot['Total_Ventas'] = pivot.sum(axis=1)

# Ordenar los juegos por total de ventas (de mayor a menor)
pivot_sorted = pivot.sort_values(by='Total_Ventas', ascending=False)

# Para graficar, usamos solo la columna 'Total_Ventas' ordenada
# También podemos graficar las ventas en diferentes plataformas si quieres

# Gráfico de barras ordenado
plt.figure(figsize=(12,8))
ax = pivot_sorted['Total_Ventas'].plot(kind='bar')
ax.set_title('Top 10 Juegos Más Vendidos')
ax.set_xlabel('Juegos')
ax.set_ylabel('Ventas Totales (Millones en USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Mostrar la tabla ordenada (opcional)
print(pivot_sorted[['Total_Ventas']])
# Out:
# platform                        Total_Ventas
# name
# Wii Sports                             82.54
# Grand Theft Auto V                     56.58
# Super Mario Bros.                      45.31
# Tetris                                 35.84
# Mario Kart Wii                         35.52
# Wii Sports Resort                      32.77
# Pokemon Red/Pokemon Blue               31.38
# Call of Duty: Black Ops                30.82
# Call of Duty: Modern Warfare 3         30.60
# New Super Mario Bros.                  29.80

# %%
# Compara las Ventas de los Mismos Juegos en Otras Plataformas

# Paso 1: Obtener los 10 juegos más vendidos en todo el dataset
top_10_juegos = games.groupby('name')['total_sales'].sum().reset_index()
top_10_juegos = top_10_juegos.sort_values(by='total_sales', ascending=False).head(10)
nombres_top_juegos = top_10_juegos['name'].tolist()

# Paso 2: Filtrar solo los datos de estos 10 juegos
juegos_filtrados = games[games['name'].isin(nombres_top_juegos)]

# Paso 3: Determinar las plataformas donde estos 10 juegos tienen mayor venta total
ventas_por_plataforma = juegos_filtrados.groupby('platform')['total_sales'].sum().reset_index()
ventas_por_plataforma = ventas_por_plataforma.sort_values(by='total_sales', ascending=False)

# Seleccionamos las top N plataformas donde se venden estos 10 juegos
top_n_plataformas = ventas_por_plataforma['platform'].head(10).tolist()

# Paso 4: Filtrar nuevamente para incluir solo estos juegos y estas plataformas
juegos_filtrados_top_platforms = juegos_filtrados[juegos_filtrados['platform'].isin(top_n_plataformas)]

# Paso 5: Agrupar por juego y plataforma para obtener ventas específicas
ventas_por_juego_plataforma = juegos_filtrados_top_platforms.groupby(['name', 'platform'])['total_sales'].sum().reset_index()

# Crear una tabla pivote con los nombres de los juegos como índice y plataformas como columnas
pivot = pd.pivot_table(
    ventas_por_juego_plataforma,
    index='name',
    columns='platform',
    values='total_sales',
    fill_value=0
)

# Ordenar los juegos por total de ventas en esas plataformas
pivot['Total_Ventas'] = pivot.sum(axis=1)
pivot_sorted = pivot.sort_values(by='Total_Ventas', ascending=False)

# Graficar barras agrupadas (side-by-side)
ax = pivot_sorted.drop(columns='Total_Ventas').plot(
    kind='bar',
    figsize=(14,8),
    width=0.8
)

ax.set_title('Distribución de los 10 Juegos Más Vendidos en Plataformas Principales')
ax.set_xlabel('Juegos')
ax.set_ylabel('Ventas (Millones en USD')
plt.xticks(rotation=45)
plt.legend(title='Plataformas')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DEL COMPARATIVO DEL COMPORTAMIENTO DE LAS VENTAS DE UN JUEGO EN DIVERSAS PLATAFORMAS**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# El estudio de las ventas por juego revela cómo algunos títulos se convierten en fenómenos de ventas, impulsando significativamente el rendimiento de plataformas específicas.
#
# Wii Sports es un claro ejemplo, con aproximadamente 82 millones de unidades vendidas exclusivamente en Wii. Este dato subraya el poder de un juego exclusivo para consolidar una plataforma en el mercado. De manera similar, Super Mario Bros., con cerca de 45 millones de unidades vendidas principalmente en NES (aproximadamente 40 millones), demuestra la influencia perdurable de los clásicos y su impacto en la historia de la industria.
#
# Otros títulos icónicos confirman esta tendencia:
#
# Tetris alcanzó casi 35 millones de unidades, la mayoría en Game Boy (unos 30 millones).
#
# Pokémon Red/Blue tuvo ventas casi exclusivas en Game Boy (alrededor de 30 millones).
#
# Mario Kart Wii y Wii Sports Resort vendieron aproximadamente 35 y 30 millones, respectivamente, ambos exclusivamente en Wii.
#
# Estos ejemplos destacan cómo las franquicias icónicas y los juegos exclusivos no solo consolidan su éxito, sino que también impulsan la adopción de plataformas específicas.
#
# Un hallazgo particularmente interesante es que PlayStation 2 (PS2), la plataforma número uno en ventas globales totales acumuladas, no figura entre las principales plataformas de los 10 juegos más vendidos. Esto sugiere que el éxito de PS2 no dependió de unos pocos títulos superventas, sino de un catálogo excepcionalmente amplio y diverso que mantuvo un alto volumen de ventas constantes a lo largo de su prolongado ciclo de vida.
#
# **Conclusión**
#
# El análisis confirma que la exclusividad y la popularidad de ciertos juegos son factores clave que pueden disparar las ventas de sus respectivas plataformas, como se vio con Wii Sports en Wii o Super Mario Bros. en NES. La trayectoria de plataformas como PS2 y Xbox 360, con su extensa base instalada y prolongado ciclo comercial, también refleja cómo una oferta constante y variada de juegos contribuye a un éxito acumulado masivo. En síntesis, el triunfo en el mercado de videojuegos está intrínsecamente ligado a una combinación de exclusividad, atractivo popular y la capacidad de llegar a diversas generaciones y tipos de dispositivos, lo que da forma a un mercado dinámico y constantemente cambiante.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has logrado articular con gran claridad cómo ciertos títulos exclusivos han sido determinantes en el posicionamiento y éxito de sus respectivas plataformas.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **DISTRIBUCION GENERAL DE LAS VENTAS GLOBALES TOTALES DE LOS JUEGOS POR GENEROS**
# </div>

# %%
# Distribución General de los Juegos por Género y su Rentabilidad

# Agrupar por género y sumar ventas globales totales
venta_por_generos = games.groupby("genre")["total_sales"].sum().reset_index()
venta_por_generos = venta_por_generos.sort_values("total_sales", ascending=False).reset_index(drop=True)
print(venta_por_generos)

# Crear el gráfico de barras
venta_por_generos.plot(kind="bar",
                       x="genre",
                       y="total_sales",
                       color="blueviolet",
                       title="Ventas Globales Totales por Géneros",
                       xlabel="Género",
                       ylabel="Ventas Globales Totales (Millones en USD)",
                       rot=45,
                       figsize=(10,5),
                       legend=False)
plt.grid(axis='y')
plt.show()
# Out:
#            genre  total_sales
# 0         Action      1744.17
# 1         Sports      1331.27
# 2        Shooter      1052.45
# 3   Role-Playing       934.56
# 4       Platform       827.77
# 5           Misc       802.51
# 6         Racing       728.67
# 7       Fighting       447.53
# 8     Simulation       389.97
# 9         Puzzle       242.57
# 10     Adventure       237.59
# 11      Strategy       174.23

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DE LA DISTRIBUCION GENERAL DE LAS VENTAS GLOBALES TOTALES DE LOS JUEGOS POR GENEROS**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Al analizar la distribución de las ventas globales totales por género, se observa una clara segmentación en la rentabilidad dentro de la industria de los videojuegos.
#
# Los géneros de Acción, Deportes y Shooter (Disparos) se posicionan como los más rentables y dominantes en el mercado. El género Acción encabeza la lista con unas ventas globales de aproximadamente 1,744 millones de dólares, seguido de cerca por Deportes con 1,331 millones y Shooter con 1,052 millones. Este liderazgo refleja la alta demanda y la amplia aceptación de estos géneros entre el público global.
#
# En contraste, géneros como Estrategia y Aventura muestran ventas significativamente menores, con 174 millones y 238 millones respectivamente. Esto sugiere que son nichos de mercado más específicos o menos populares a escala global. Otros géneros, como Simulación, Puzle y Lucha (Fighting), también registran ventas moderadas o bajas, indicando que, si bien tienen una base de consumidores, no alcanzan las cifras récord de los géneros líderes.
#
# **Conclusión**
#
# En términos generales, los géneros de Acción y Deportes son los que consistentemente atraen a un público más amplio y, por ende, generan los mayores ingresos. Por otro lado, los géneros con ventas más bajas tienden a ser más especializados o dirigidos a segmentos de mercado específicos, lo que limita su alcance y potencial de ingresos a nivel global.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Excelente trabajo! Se ve claramente que los juegos de acción y deportes lideran en ventas. Los géneros de rol y shooter también destacan, aunque en menor medida. En cambio, los de estrategia, aventura y puzzle muestran ventas más bajas, lo que indica una demanda más limitada.
#
# </div>

# %% [markdown]
# <div style="background-color: #F0F0F0; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO 4: CREACION DE PERFILES REGIONALES
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **VENTAS REGIONALES POR LAS 5 PLATAFORMAS PRINCIPALES**
# </div>

# %%
# Ventas de las 5 Plataformas Principales por Región

# Definir las plataformas principales según ventas totales globales
top_5_platforms = ["PS2", "X360", "PS3", "Wii", "DS"]

# Filtrar los datos para esas plataformas
ventas_top5 = games[games["platform"].isin(top_5_platforms)]

# Agrupar por plataforma y sumar ventas por región
ventas_por_region = ventas_top5.groupby("platform")[["na_sales", "eu_sales", "jp_sales"]].sum().reset_index()
ventas_por_region.columns = ["platform", "North America Sales", "Europe Sales", "Japan Sales"]


# Mostrar los Resultados
print(ventas_por_region)

# Creación del Gráfico
ax = ventas_por_region.set_index("platform").T.plot(
    kind='bar',
    figsize=(14,8),
    rot=0,
    colormap='viridis'
)

ax.set_xlabel("Región")
ax.set_ylabel("Ventas (Millones en USD)")
ax.set_title("Ventas de las 5 Plataformas Principales por Región")
plt.legend(title='Plataforma')
plt.tight_layout()
plt.show()
# Out:
#   platform  North America Sales  Europe Sales  Japan Sales
# 0       DS               382.40        188.89       175.57
# 1      PS2               583.84        339.29       139.20
# 2      PS3               393.49        330.29        80.19
# 3      Wii               496.90        262.21        69.33
# 4     X360               602.47        270.76        12.43

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **DESCRIPCION DE LAS VARIACIONES DE LAS 5 PLATAFORMAS PRINCIPALES ENTRE LAS REGIONES**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Se identificaron las cinco plataformas con mayores ventas globales: PlayStation 2 (PS2), Xbox 360 (X360), PlayStation 3 (PS3), Wii y Nintendo DS (DS). A continuación, se presenta un análisis de sus cuotas de mercado en las regiones de Norteamérica, Europa y Japón.
#
# **Ventas en Norteamérica**
#
# La plataforma que domina claramente en esta región es Xbox 360, con ventas por aproximadamente 602.47 millones de USD. Le sigue PlayStation 2 con 583.84 millones, y luego Wii con 496.90 millones. La alta preferencia por Xbox 360 en Norteamérica refleja una fuerte adopción de consolas de Microsoft durante su ciclo de vida, posiblemente debido a campañas de marketing efectivas y una amplia oferta de juegos. PlayStation 2, que es la plataforma líder en ventas globales, mantiene una presencia significativa, aunque menor que la Xbox 360, mientras que Nintendo Wii también tiene una cuota importante, destacando la popularidad de sus juegos innovadores y su enfoque en el público familiar.
#
# **Ventas en Europa**
#
# En Europa, la tendencia es similar a Norteamérica, aunque con algunas variaciones. PlayStation 2 lidera con aproximadamente 339.29 millones de USD en ventas, seguida por Xbox 360 con 270.76 millones y Wii con 262.21 millones. La diferencia notable aquí es que PS2 mantiene una posición más fuerte relativa a otras regiones, demostrando su liderazgo mundial, probablemente debido a su larga vida útil y popularidad duradera en mercados europeos. La presencia significativa del Wii también indica la aceptación del enfoque innovador y accesible de Nintendo en esta región.
#
# **Ventas en Japón**
#
# En Japón, las ventas son considerablemente menores comparadas con Norteamérica y Europa para estas plataformas principales, por lo que el mercado es más pequeño. Xbox 360 tiene solo alrededor de 12.43 millones en ventas, reflejando su menor penetración en el mercado japonés. Por otro lado, PlayStation 2 aún mantiene una presencia notable con aproximadamente 139.20 millones, aunque se queda con el segundo lugar en ventas, lo que evidencia su longevidad y preferencia entre los consumidores japoneses. Wii también tiene ventas relevantes (69.33 millones), apoyando la tendencia hacia consolas de juegos que ofrecen experiencias familiares e innovadoras.
#
# **Conclusión**
#
# Las cuotas de mercado varían significativamente entre regiones para estas plataformas principales. Xbox 360 domina en Norteamérica, mientras que PlayStation 2 mantiene una fuerte presencia en las 3 regiones, debido a su longevidad y aceptación duradera. La consola Wii logra buenas ventas en todas las regiones, especialmente en Norteamérica y Europa, gracias a su propuesta innovadora y orientada al público familiar.
#
# Este análisis refleja cómo las preferencias regionales influyen en la distribución del mercado de consolas de juegos y subraya la importancia de adaptar estrategias comerciales según cada región.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **VENTAS REGIONALES POR LOS 5 GENEROS PRINCIPALES**
# </div>

# %%
# Ventas de las 5 Géneros Principales por Región

# Definir los cinco géneros principales
top_5_genres = ["Action", "Sports", "Shooter", "Role-Playing", "Platform"]

# Filtrar los datos para esos géneros
ventas_top5_genres = games[games["genre"].isin(top_5_genres)]

# Agrupar por género y sumar ventas por región
ventas_por_genero_y_region = ventas_top5_genres.groupby("genre")[["na_sales", "eu_sales", "jp_sales"]].sum().reset_index()
ventas_por_genero_y_region.columns = ["genre", "North America Sales", "Europe Sales", "Japan Sales"]
ventas_por_genero_y_region

# Mostrar los Resultados
print(ventas_por_genero_y_region)

# Creación del Gráfico
ax = ventas_por_genero_y_region.set_index("genre").T.plot(
    kind='bar',
    figsize=(14,8),
    rot=0,
    colormap='Set2'
)

ax.set_xlabel("Región")
ax.set_ylabel("Ventas (Millones en USD)")
ax.set_title("Ventas de los 5 Géneros Principales por Región")
plt.legend(title='Género')
plt.tight_layout()
plt.show()
# Out:
#           genre  North America Sales  Europe Sales  Japan Sales
# 0        Action               879.01        519.13       161.43
# 1      Platform               445.50        200.35       130.83
# 2  Role-Playing               330.81        188.71       355.41
# 3       Shooter               592.24        317.34        38.76
# 4        Sports               684.43        376.79       135.54

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DE LAS DIFERENCIAS DE LOS 5 GENEROS PRINCIPALES ENTRE LAS REGIONES**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Se seleccionaron los cinco géneros con mayores ventas globales: Acción, Deportes, Disparos(Shooter), Rol-Playing y Plataformas. A continuación, se analiza cómo se distribuyen sus ventas en las regiones de Norteamérica, Europa y Japón, destacando las diferencias regionales en preferencias y comportamiento del mercado.
#
# **Ventas en Norteamérica**
#
# El género de Acción lidera con aproximadamente 879.01 millones de USD en ventas, seguido por Deportes con 684.43 millones y Disparos(Shooter) con 592.24 millones. La popularidad del género Acción en Norteamérica refleja una fuerte preferencia por juegos dinámicos y de alta adrenalina, típicos de este género. Los juegos deportivos también tienen una presencia significativa, probablemente debido a la cultura deportiva activa en la región, que incluye varios deportes profesionales con ligas importantes como la NFL, la NBA, la MLB y la liga de Hockey.
#
# **Ventas en Europa**
#
# En Europa, el género Acción también ocupa la primera posición con 519.13 millones de USD, aunque con una diferencia menor respecto a Deportes que alcanza la cifra de 376.79 millones y Disparos(Shooter) con una cifra de 317.34 millones en ventas. La tendencia indica que los juegos de acción siguen siendo muy populares, pero los deportes mantienen una presencia importante.
#
# **Ventas en Japón**
#
# En Japón, las ventas muestran un patrón diferente: el género Rol-Playing destaca con aproximadamente 355.41 millones de USD en ventas, superando a Acción que obtuvo 161.43 millones y Disparos(Shooter) con una cifra lograda de 38.76 millones en ventas. Esto evidencia que los juegos de rol tienen una fuerte aceptación en el mercado japonés, donde suelen ser más populares debido a características culturales específicas. Los juegos de acción y shooter tienen menor penetración en esta región. A su vez, los juegos de Deportes no tienen una demanda fuerte, seguramente debido a la falta de una variedad de deportes practicados profesionalmente en ese país.
#
# **Conclusión**
#
# Las preferencias por géneros varían notablemente entre regiones. Mientras que en Norteamérica y Europa predominan los géneros Acción y Deportes, en Japón el género Rol-Playing domina claramente las ventas. Estas diferencias reflejan las distintas culturas de juegos y tendencias del mercado regionales, subrayando la importancia de adaptar las estrategias de desarrollo y marketing según cada región para maximizar el éxito comercial.
#
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **INCIDENCIA DE LAS CLASIFICACIONES DE "ESRB" EN CADA UNA DE LAS VENTAS REGIONALES**
# </div>

# %%
# Análisis si las Clasificaciones de "ESRB" afectan a las ventas en las Regiones

# Filtrar solo ratings conocidos
ratings_conocidos = ['Adults Only', 'Early Childhood', 'Everyone', 'Everyone 10+', 'Kids to Adults', 'Mature', 'Rating Pending', 'Teen']
ventas_filtradas = games[games['rating_names'].isin(ratings_conocidos)]

# Agrupar y sumar
ventas_por_rating = ventas_filtradas.groupby('rating_names')[['na_sales', 'eu_sales', 'jp_sales']].sum().reset_index()
ventas_por_rating.columns = ["rating_names", "North America Sales", "Europe Sales", "Japan Sales"]

print(ventas_por_rating)


# Gráfico
ax = ventas_por_rating.set_index('rating_names').T.plot(
    kind='bar',
    figsize=(14,8),
    rot=0,
    colormap='Pastel1'
)

ax.set_xlabel("Región")
ax.set_ylabel("Ventas (Millones en USD)")
ax.set_title("Ventas por Clasificación ESRB en cada Región")
plt.legend(title='Clasificación ESRB')
plt.tight_layout()
plt.show()
# Out:
#       rating_names  North America Sales  Europe Sales  Japan Sales
# 0      Adults Only                 1.26          0.61         0.00
# 1  Early Childhood                 1.53          0.11         0.00
# 2         Everyone              1292.99        710.25       198.11
# 3   Kids to Adults                 2.56          0.27         1.46
# 4           Mature               748.48        483.97        64.24
# 5   Rating Pending                 0.00          0.08         0.00
# 6             Teen               759.75        427.03       151.40

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **COMO AFECTAN LAS CLASIFICACIONES DE "ESRB" A LAS VENTAS EN LAS REGIONES**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Se analizó si las clasificaciones de la Entertainment Software Rating Board (ESRB) tienen un impacto significativo en las ventas de videojuegos en distintas regiones. Para ello, se filtraron los datos de acuerdo con las clasificaciones conocidas y se agruparon por región para evaluar sus ventas totales.
#
# **Ventas en Norteamérica**
#
# Las clasificaciones que predominan en esta región son "Everyone" (Todos) y "Teen" (Adolescentes), con ventas de aproximadamente 1,292.99 millones y 759.75 millones de USD respectivamente. La clasificación "Mature" (Maduro) también tiene una presencia importante, con ventas cercanas a 748.48 millones. Esto indica que en Norteamérica hay una fuerte preferencia por juegos aptos para todos los públicos y adolescentes, además de títulos más maduros, reflejando una diversidad en los gustos y preferencias del mercado.
#
# **Ventas en Europa**
#
# En Europa, la tendencia es similar: "Everyone" lidera con 710.25 millones de USD, seguido por "Teen" con 427.03 millones y "Mature" con 483.97 millones. La presencia significativa de estas clasificaciones sugiere que los juegos dirigidos a públicos amplios y adolescentes son muy populares, aunque también existe una demanda considerable por juegos para un público maduro.
#
# **Ventas en Japón**
#
# En Japón, las ventas están mucho más concentradas en la clasificación "Everyone", con aproximadamente 198.11 millones de USD, seguida por "Teen" con 151.40 millones y "Mature" con solo 64.24 millones. La clasificación "Adults Only" (Solo Adultos) no muestra ventas significativas en ninguna región, lo que refleja que este tipo de contenido es menos aceptado o demandado en los mercados analizados.
#
# **Conclusión**
#
# Las clasificaciones ESRB parecen influir notablemente en las ventas regionales, especialmente en Norteamérica y Europa, donde títulos para todos los públicos ("Everyone") y adolescentes ("Teen") representan la mayor parte del mercado. En Japón, aunque también predominan estas categorías, la demanda por contenido maduro es menor comparada con Occidente. Estos patrones sugieren que la percepción y aceptación de las clasificaciones ESRB varían según la región, afectando directamente las estrategias de desarrollo y marketing para maximizar las ventas.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis integral por región ofrece una visión muy completa del comportamiento del mercado de videojuegos, abordando no solo plataformas y géneros, sino también el impacto de las clasificaciones ESRB. Supiste destacar con claridad cómo las preferencias regionales configuran un panorama muy diverso, donde el liderazgo de ciertas consolas o géneros no se replica de forma homogénea en todas las zonas. También es muy útil la manera en que conectas estas diferencias con elementos culturales y comerciales que explican esas variaciones.
#
# </div>

# %% [markdown]
# <div style="background-color: #F0F0F0; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO 5: PRUEBA DE HIPOTESIS
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **HIPOTESIS 1: LAS CALIFICACIONES PROMEDIO DE LOS USUARIOS PARA LAS PLATAFORMAS XBOX ONE Y PC SON LAS MISMAS**
# </div>

# %%
# Hipótesis Sobre las Calificaciones Promedio para las Plataformas "Xbox One" y "PC"

# Hipótesis Nula
print()
print("Hipótesis Nula(H₀): Los calificaciones promedio de los usuarios para las plataformas Xbox One y PC son iguales.")
print()
# Hipótesis Alternativa
print("Hipótesis Alternativa(H₁): Los calificaciones promedio de los usuarios para las plataformas Xbox One y PC son diferentes.")
print()
# Prueba Estadística Seleccionada
print("Pruebas Seleccionadas: Igualdad de las medias de dos poblaciones de dos colas, con una prueba t de Student. Se selecciona esta prueba estadística ya que el objetivo es\ndeterminar si existe alguna diferencia en las calificaciones promedio de los usuarios para las plataformas Xbox One y PC.")
print()
# Determinar el valor Alfa
print("Valor alpha = 0.05")
# Out:
# Hipótesis Nula(H₀): Los calificaciones promedio de los usuarios para las plataformas Xbox One y PC son iguales.
#
# Hipótesis Alternativa(H₁): Los calificaciones promedio de los usuarios para las plataformas Xbox One y PC son diferentes.
#
# Pruebas Seleccionadas: Igualdad de las medias de dos poblaciones de dos colas, con una prueba t de Student. Se selecciona esta prueba estadística ya que el objetivo es
# determinar si existe alguna diferencia en las calificaciones promedio de los usuarios para las plataformas Xbox One y PC.
#
# Valor alpha = 0.05

# %% [markdown]
# **FORMULACION DE LAS HIPOTESIS RESPECTO A LAS CALIFICACIONES PROMEDIO DE LOS USUARIOS PARA LAS PLATAFORMAS XBOX ONE Y PC**
#
# El objetivo del análisis es determinar si existen diferencias significativas en las calificaciones promedio otorgadas por los usuarios a las plataformas Xbox One y PC. Se selecciona una prueba estadística bilateral (de dos colas) basada en la comparación de medias entre dos poblaciones independientes, específicamente la prueba t de Student, dado que se busca detectar cualquier diferencia, sin especificar cuál género tiene calificaciones mayores o menores

# %%
# Hipótesis 1

# Filtrar los datos
scores_xbox_one = games[games['platform'] == 'XOne']['user_score'].dropna()
scores_pc = games[games['platform'] == 'PC']['user_score'].dropna()

# Nivel de significancia
alpha = 0.05

# Prueba de igualdad de varianzas (Levene)
stat_levene, p_levene = st.levene(scores_xbox_one, scores_pc)

print(f"Estadístico Levene: {stat_levene : .4f}")
print(f"P-valor Levene: {p_levene : .4f}")

# Decidir si las varianzas son iguales
if p_levene > alpha:
    print("Las varianzas son iguales (no se rechaza H0). Se puede usar la prueba t con varianzas iguales.")
else:
    print("Las varianzas no son iguales (se rechaza H0). Se recomienda usar la prueba t sin asumir varianzas iguales.")
# Out:
# Estadístico Levene:  1.2213
# P-valor Levene:  0.2694
# Las varianzas son iguales (no se rechaza H0). Se puede usar la prueba t con varianzas iguales.

# %%
# Prueba t student 

# Filtrar los datos
scores_xbox_one = games[games['platform'] == 'XOne']['user_score'].dropna()
scores_pc = games[games['platform'] == 'PC']['user_score'].dropna()

# Nivel de Significancia
alpha =0.05

t_stat, p_value = st.ttest_ind(scores_xbox_one, scores_pc, equal_var=True)
print(f"Estadístico t: {t_stat:.4f}")
print(f"P-valor: {p_value:.4f}")

# Interpretación final
if p_value < alpha:
    print("Se rechaza la hipótesis nula: hay una diferencia significativa en las calificaciones promedio entre Xbox One y PC.")
else:
    print("No se puede rechazar la hipótesis nula: no hay una diferencia significativa en las calificaciones promedio entre Xbox One y PC.")
# Out:
# Estadístico t: -4.3683
# P-valor: 0.0000
# Se rechaza la hipótesis nula: hay una diferencia significativa en las calificaciones promedio entre Xbox One y PC.

# %%
# Diagarama de Caja de las Calificaciones Promedio por Plataforma: Xbox One y PC

# Datos filtrados
scores_xbox_one = games[games['platform'] == 'XOne']['user_score'].dropna()
scores_pc = games[games['platform'] == 'PC']['user_score'].dropna()

# Crear un DataFrame para el boxplot
data_platform = pd.DataFrame({
    'User Score': pd.concat([scores_xbox_one, scores_pc]),
    'Platform': ['Xbox One'] * len(scores_xbox_one) + ['PC'] * len(scores_pc)
})

sns.set(style="whitegrid")

# Crear el boxplot
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='Platform', y='User Score', data=data_platform)
ax.set_title('Distribución de calificaciones por plataforma: Xbox One vs PC')
plt.xlabel('Plataforma')
plt.ylabel('Calificación de usuario')

plt.show()

# %%
# Calcula la Media, la Varianza, Desviación Estándar y Mediana de las Calificaciones Promedio de las Plataformas Xbox One y PC

# Filtrar los datos por plataformas
scores_xbox_one = games[games['platform'] == 'XOne']['user_score'].dropna()
scores_pc = games[games['platform'] == 'PC']['user_score'].dropna()

# Obtener los cálculos del promedio de ias calificaciones de usuarios, varianza, desviación estándar y mediana  
# de la plataforma Xbox
mean_scores_xbox_one = scores_xbox_one.mean()
var_scores_xbox_one = np.var(scores_xbox_one)
sigma_scores_xbox_one = np.std(scores_xbox_one)
mediam_scores_xbox_one = scores_xbox_one.median()

# Obtener los cálculos del promedio de ias calificaciones de usuarios, varianza, desviación estándar y mediana  
# de la plataforma PC
mean_scores_pc = scores_pc.mean()
var_scores_pc = np.var(scores_pc)
sigma_scores_pc = np.std(scores_pc)
mediam_scores_pc = scores_pc.median()

# Imprimir los resultados de las medidas estadísticas
print("Plataforma Xbox One")
print("La media del promedio de la calificaciones de la plataforma Xbox One es:", mean_scores_xbox_one)
print("La varianza del promedio de la calificaciones de la plataforma Xbox One es:",var_scores_xbox_one)
print("La desviación estándar del promedio de la calificaciones de la plataforma Xbox One es:",sigma_scores_xbox_one)
print("La mediana del promedio de la calificaciones de la plataforma Xbox One es:",mediam_scores_xbox_one)
print()
print("Plataforma PC")
print("La media del promedio de la calificaciones de la plataforma PC es:",mean_scores_pc)
print("La varianza del promedio de la calificaciones de la plataforma PC es:",var_scores_pc)
print("La desviación estándar del promedio de la calificaciones de la plataforma PC es:",sigma_scores_pc)
print("La mediana del promedio de la calificaciones de la plataforma PC es:",mediam_scores_pc)
# Out:
# Plataforma Xbox One
# La media del promedio de la calificaciones de la plataforma Xbox One es: 6.521428571428572
# La varianza del promedio de la calificaciones de la plataforma Xbox One es: 1.8965188383045526
# La desviación estándar del promedio de la calificaciones de la plataforma Xbox One es: 1.377141546212499
# La mediana del promedio de la calificaciones de la plataforma Xbox One es: 6.8
#
# Plataforma PC
# La media del promedio de la calificaciones de la plataforma PC es: 7.062467532467533
# La varianza del promedio de la calificaciones de la plataforma PC es: 2.3377471580367684
# La desviación estándar del promedio de la calificaciones de la plataforma PC es: 1.5289693123266956
# La mediana del promedio de la calificaciones de la plataforma PC es: 7.5

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DE LA HIPOTESIS 1: SI LAS CALIFICACIONES PROMEDIO DE LOS USUARIOS PARA LAS PLATAFORMAS XBOX ONE Y PC SON LAS MISMAS**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Para evaluar si existen diferencias significativas en las calificaciones promedio de los usuarios entre las plataformas Xbox One y PC, se realizaron varias pruebas estadísticas y análisis descriptivos.
#
# **Prueba de Igualdad de Varianzas (Levene)**
#
# El estadístico de Levene fue 1.2213 con un p-valor de 0.2694, lo que indica que no hay evidencia suficiente para rechazar la hipótesis nula de igualdad de varianzas. Por lo tanto, podemos asumir que las varianzas en ambas plataformas son iguales y se procedió a realizar una prueba t de student para medias independientes, bajo esta suposición.
#
# **Prueba t de Student**
#
# El estadístico t obtenido fue -4.3683 con un p-valor muy cercano a cero (0.0000). Esto nos lleva a rechazar la hipótesis nula de que las medias sean iguales. En otras palabras, existe una diferencia estadísticamente significativa en las calificaciones promedio entre Xbox One y PC.
#
# **Medidas Descriptivas**
#
# La media en Xbox One es aproximadamente 6.52, con una varianza de 1.90 y una desviación estándar de 1.38; la mediana es 6.8, indicando una distribución relativamente simétrica.
# La media en PC es aproximadamente 7.06, con una varianza mayor (2.34) y una desviación estándar similar (1.53); la mediana es 7.5, ligeramente superior a la de Xbox One.
#
# **Análisis Visual del Diagrama de Caja y Bigotes**
#
# La caja en Xbox One es más simétrica, con un rango aproximado de 5.9 a 7.5, donde la mediana se encuentra ligeramente por encima del centro del rango, indicando una distribución equilibrada.
#
# La caja en PC es más grande (de aproximadamente 6.1 a 8.1), con un rango superior que va hasta 9.1, mostrando mayor dispersión y presencia de valores atípicos por debajo del bigote inferior (de aproximadamente 3.2 a 0.2).
#
# El bigote inferior en PC es notablemente más largo (más del doble que el superior), sugiriendo que hay varios valores atípicos bajos en esta plataforma, mientras que en Xbox One estos valores son menos frecuentes.
#
# **Conclusión**
#
# Los resultados estadísticos confirman que existe una diferencia significativa en las calificaciones promedio entre las plataformas Xbox One y PC, siendo estas últimas ligeramente mejor valoradas en promedio (medias de 6.52 vs 7.06). La variabilidad también difiere, siendo mayor en PC debido a la presencia de valores atípicos bajos y una caja más grande, lo cual indica mayor dispersión en las calificaciones.
#
# En resumen, podemos concluir que las calificaciones promedio no son iguales entre ambas plataformas, apoyando así la hipótesis alternativa: existe una diferencia significativa en las calificaciones promedio entre Xbox One y PC.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has estructurado muy bien el análisis de esta hipótesis, integrando de forma clara tanto los resultados estadísticos como las medidas descriptivas y visuales. Tu interpretación de la prueba de Levene y la prueba t es precisa y bien argumentada, y lograste complementar el análisis numérico con observaciones detalladas del diagrama de caja, lo que añade una capa visual muy útil para comprender la dispersión y simetría en los datos.
#
# </div>

# %% [markdown]
# <div style="background-color: #d3d3d3; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **HIPOTESIS 2: LAS CALIFICACIONES PROMEDIO DE LOS USUARIOS PARA LOS GENEROS DE ACCION Y DEPORTES SON DIFERENTES**
# </div>

# %%
# Hipótesis Sobre las Calificaciones Promedio de los Usuarios para los Géneros de "Acción" y "Deportes"

# Hipótesis Nula
print()
print("Hipótesis Nula(H₀): Los calificaciones promedio de los usuarios para los géneros de Acción y Deportes son iguales.")
print()
# Hipótesis Alternativa
print("Hipótesis Alternativa(H₁): Los calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.")
print()
# Prueba Estadística Seleccionada
print("Prueba Seleccionada: Igualdad de las medias de dos poblaciones de dos colas, con una prueba t de Student. Se selecciona esta prueba estadística ya que el objetivo es determinar si hay alguna diferencia en las calificaciones promedio de los usuarios para los géneros Acción y Deportes.")
print()
# Determinar el valor Alfa
print("Valor alpha = 0.05")
# Out:
# Hipótesis Nula(H₀): Los calificaciones promedio de los usuarios para los géneros de Acción y Deportes son iguales.
#
# Hipótesis Alternativa(H₁): Los calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.
#
# Prueba Seleccionada: Igualdad de las medias de dos poblaciones de dos colas, con una prueba t de Student. Se selecciona esta prueba estadística ya que el objetivo es determinar si hay alguna diferencia en las calificaciones promedio de los usuarios para los géneros Acción y Deportes.
#
# Valor alpha = 0.05

# %% [markdown]
# **FORMULACION DE LAS HIPOTESIS RESPECTO A LAS CALIFICACIONES PROMEDIO DE LOS USUARIOS PARA LOS GENEROS "ACCION" y "DEPORTES"**
#
# El objetivo del análisis es determinar si existen diferencias significativas en las calificaciones promedio otorgadas por los usuarios a los géneros de Acción y Deportes. Se selecciona una prueba estadística bilateral (de dos colas) basada en la comparación de medias entre dos poblaciones independientes, específicamente la prueba t de Student, dado que se busca detectar cualquier diferencia, sin especificar cuál género tiene calificaciones mayores o menores.

# %%
# Hipótesis 2

# Prueba de Levene, para Determinar si las Varianzas de los Dos Grupos son Iguales.

# Filtrar las calificaciones por género y eliminar Valores Ausentes
action_scores = games[games["genre"] == "Action"]["user_score"].dropna()
sports_scores = games[games["genre"] == "Sports"]["user_score"].dropna()

# Nivel de Significancia
alpha = 0.05

# Prueba de Levene para igualdad de varianzas
stat_levene, p_levene = st.levene(action_scores, sports_scores)

print(f"Estadístico de Levene: {stat_levene : .4f}")
print(f"Valor p de Levene: {p_levene : .4f}")

# Decidir si las varianzas son iguales
if p_levene > alpha:
    print("Las varianzas son iguales (no se rechaza H0). Se puede usar la prueba t con varianzas iguales.")
else:
    print("Las varianzas no son iguales (se rechaza H0). Se recomienda usar la prueba t sin asumir varianzas iguales.")
# Out:
# Estadístico de Levene:  14.1329
# Valor p de Levene:  0.0002
# Las varianzas no son iguales (se rechaza H0). Se recomienda usar la prueba t sin asumir varianzas iguales.

# %%
# Prueba t student 

# Filtrar las calificaciones por género y eliminar Valores Ausentes
action_scores = games[games["genre"] == "Action"]["user_score"].dropna()
sports_scores = games[games["genre"] == "Sports"]["user_score"].dropna()

# Nivel de Significancia
alpha =0.05

t_stat, p_value = st.ttest_ind(action_scores, sports_scores, equal_var=False)

print(f"Estadístico t: {t_stat: .4f}")
print(f"Valor p: {p_value: 4f}")

# Interpretación final
if p_value < alpha:
    print("Se rechaza la hipótesis nula: hay diferencia significativa entre las calificaciones promedio de los usuarios para los géneros Action y Sports.")
else:
    print("No se puede rechazar la hipótesis nula: no hay diferencia significativa entre las calificaciones promedio de los usuarios para los géneros Action y Sports.")
# Out:
# Estadístico t:  1.5775
# Valor p:  0.114838
# No se puede rechazar la hipótesis nula: no hay diferencia significativa entre las calificaciones promedio de los usuarios para los géneros Action y Sports.

# %%
# Diagrama de Caja de las Calificaciones Promedio por Género: Acción y Deportes

# Filtrar los datos por género
scores_action = games[games['genre'] == 'Action']['user_score'].dropna()
scores_sports = games[games['genre'] == 'Sports']['user_score'].dropna()

# Crear un DataFrame para facilitar la visualización
data_games = pd.DataFrame({
    'Score': pd.concat([scores_action, scores_sports]),
    'Genre': ['Action'] * len(scores_action) + ['Sports'] * len(scores_sports)
})


sns.set(style="whitegrid")

# Crear el boxplot
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='Genre', y='Score', data=data_games)
ax.set_title('Comparación de calificaciones Promedio por Género: Acción vs Deportes')
plt.xlabel('Género')
plt.ylabel('Calificación de usuario')

plt.show()

# %%
# Calcula la Media, la Varianza, Desviación Estándar y Mediana de las Calificaciones Promedio de los Géneros Acción y Deportes

# Filtrar los datos por géneros 
scores_action = games[games['genre'] == 'Action']['user_score'].dropna()
scores_sports = games[games['genre'] == 'Sports']['user_score'].dropna()

# Obtener los cálculos del promedio de ias calificaciones de usuarios, varianza, desviación estándar y mediana  
# del gémero Acción
mean_scores_action = scores_action.mean()
var_scores_action = np.var(scores_action)
sigma_scores_action = np.std(scores_action)
mediam_scores_action = scores_action.median()

# Obtener los cálculos del promedio de ias calificaciones de usuarios, varianza, desviación estándar y mediana  
# del género Deportes
mean_scores_sports = scores_sports.mean()
var_scores_sports = np.var(scores_sports)
sigma_scores_sports = np.std(scores_sports)
mediam_scores_sports = scores_sports.median()

# Imprimir los resultados de las medidas estadísticas
print("Género Acción")
print("La media del promedio de las calificaciones del género Acción es:", mean_scores_action)
print("La varianza del promedio de las calificaciones del género Acción es:",var_scores_action)
print("La desviación estándar del promedio de las calificaciones del género Acción es:",sigma_scores_action)
print("La mediana del promedio de las calificaciones del género Acción es:",mediam_scores_action)
print()
print("Género Deportes")
print("La media del promedio de las calificaciones del género Deportes es:",mean_scores_sports)
print("La varianza del promedio de las calificaciones del género Deportes es:",var_scores_sports)
print("La desviación estándar del promedio de las calificaciones del género Deportes es:",sigma_scores_sports)
print("La mediana del promedio de las calificaciones del género Deportes es:",mediam_scores_sports)
# Out:
# Género Acción
# La media del promedio de las calificaciones del género Acción es: 7.054043715846995
# La varianza del promedio de las calificaciones del género Acción es: 2.03063665382663
# La desviación estándar del promedio de las calificaciones del género Acción es: 1.4250040890561086
# La mediana del promedio de las calificaciones del género Acción es: 7.4
#
# Género Deportes
# La media del promedio de las calificaciones del género Deportes es: 6.961196736174069
# La varianza del promedio de las calificaciones del género Deportes es: 2.594160671177017
# La desviación estándar del promedio de las calificaciones del género Deportes es: 1.6106398328543279
# La mediana del promedio de las calificaciones del género Deportes es: 7.4

# %% [markdown]
# <div style="background-color: #F0E6FF; padding: 10px; font-size: 18px; font-weight: bold;">
#
# **ANALISIS DE LA HIPOTESIS 2: SI LAS CALIFICACIONES PROMEDIO DE LOS USUARIOS PARA LOS GENEROS ACCION Y DEPORTES SON DIFERENTES**
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Para evaluar si existen diferencias significativas en las calificaciones promedio de los usuarios entre los géneros de Acción y Deportes, se realizaron varias pruebas estadísticas y análisis descriptivos.
#
# **Prueba de Igualdad de Varianzas (Levene)**
#
# Se realizó una prueba t de Student para muestras independientes, con el objetivo de determinar si existen diferencias significativas en las calificaciones promedio entre los géneros Acción y Deportes. Dado que la prueba previa de Levene indicó que las varianzas no eran iguales (p-valor = 0.0002), se utilizó la versión de la prueba t sin asumir varianzas iguales (equal_var=False).
#
#
# **Prueba t de Student**
#
# Se realizó una prueba t para muestras independientes (con varianzas no asumidas iguales). El estadístico t fue aproximadamente 1.5775 con un p-valor de 0.1148.
# Dado que el p-valor es mayor que el nivel de significancia α = 0.05, no hay suficiente evidencia para rechazar la hipótesis nula de igualdad en las medias.
#
#
# **Medidas Descriptivas**
#
# La media del género Acción es aproximadamente 7.05, con una varianza de 2.03 y una desviación estándar de 1.43; la mediana es 7.4.
# La media del género Deportes es aproximadamente 6.96, con una varianza mayor de 2.59 y una desviación estándar de 1.61; la mediana también es 7.4.
#
# Estas medidas indican que, en promedio, las calificaciones otorgadas por los usuarios a ambos géneros son similares, aunque el género Deportes presenta mayor dispersión en las calificaciones.
#
# **Análisis Visual del Diagrama de Caja y Bigotes**
#
# La forma de las cajas y los bigotes indica que:
#
# 1) La distribución de calificaciones en ambos géneros es similar en tendencia central (mediana), pero con mayor dispersión en Deportes.
# 2) La presencia de valores atípicos en ambos géneros sugiere que algunos usuarios otorgaron calificaciones excepcionalmente bajas.
# 3) La diferencia en tamaño de las cajas y bigotes refleja variabilidad adicional en las calificaciones del género Deportes.
#
# **Conclusión**
#
# Los análisis estadísticos —medidas descriptivas, prueba t y visualización mediante diagrama de cajas— convergen en que no existen diferencias estadísticamente significativas entre las calificaciones promedio otorgadas a los géneros Acción y Deportes por los usuarios (p-valor = 0.1148). Aunque hay variabilidad en las distribuciones, ambas muestran tendencias similares en cuanto a puntuaciones medias y mediana.
#
# Por lo tanto, podemos concluir que los usuarios valoran estos dos géneros de manera comparable en esta muestra, por lo que no se puede rechazar la hipótesis nula.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Es clave valioso cómo explicas la elección de la prueba t sin asumir varianzas iguales, demostrando un manejo técnico adecuado. Además, al señalar que, aunque hay diferencias en la dispersión, las medias son comparables, ofreces una lectura equilibrada que no exagera los resultados.
#
# </div>

# %% [markdown]
# <div style="background-color: #D8BFD8; padding: 10px; font-size: 22px; font-weight: bold;">
# PASO 6: CONCLUSION GENERAL
# </div>

# %% [markdown]
# <div style="font-size: 16px">
#
# Este proyecto tuvo como objetivo identificar patrones de éxito en la industria de los videojuegos, analizando datos históricos de ventas, reseñas, géneros y plataformas en Norteamérica, Europa y Japón, con miras a planificar campañas publicitarias para 2017.
#
# **Tendencias Generales de la Industria.**
#
# La industria de los videojuegos experimentó un crecimiento exponencial desde el año 2000 hasta su pico alrededor de 2008-2009, impulsado por el interés del mercado y los avances tecnológicos. Sin embargo, a partir de 2009, se observa un marcado declive en el número de lanzamientos, una tendencia que continúa en disminución. Este descenso podría atribuirse a la saturación del mercado, cambios en los gustos de los consumidores (como la preferencia por el streaming) y modificaciones en el registro de datos.
#
# Las plataformas tienen ciclos de vida relativamente cortos, aproximadamente entre 6 y 7 años (tomando en consideración el período 2000-2016), con nuevas plataformas emergiendo y otras desapareciendo rápidamente. Plataformas que fueron líderes, como PS2, X360, PS3 y Wii, han visto sus ventas actuales acercarse a cero, lo que indica su poca relevancia en el gusto de los consumidores. A pesar de los análisis exhaustivos, no se identificó ninguna plataforma con un crecimiento sostenido y potencialmente rentable para 2017 dentro del dataset actual. Esto sugiere un mercado desafiante, con intensa competencia y ciclos de vida cortos para las plataformas tradicionales, además de cambios en las preferencias del consumidor debido a nuevas tecnologías, lo cual intuye un transición hacia generaciones más nuevas de consolas y dispositivos digitales, así como cambios en los hábitos de consumo, como el aumento del juego en línea, servicios de streaming y plataformas móviles.
#
# **Ventas Globales y Comportamiento de las Reseñas.**
#
# Un aspecto destacado es que, al comparar las plataformas con mayores ventas totales acumuladas, solo Xbox 360 (X360) presenta una mediana relativamente alta, lo que indica que su volumen total de ventas está concentrado en unos pocos títulos muy exitosos. Esto genera una alta dispersión en sus resultados, a diferencia de plataformas como NES, Game Boy (GB) y Atari 2600, que muestran medianas más elevadas y un rendimiento más consistente durante su ciclo de vida. Aunque estas últimas lograron ventas moderadas a altas en promedio, probablemente fueron rentables solo en ciertos períodos; si hubieran permanecido más tiempo en el mercado, podrían haber escalado aún más en las posiciones de ventas totales. En general, las diferencias en la dispersión y presencia de valores atípicos reflejan cómo algunos juegos clave pueden influir significativamente en los resultados globales de cada plataforma.
#
# En cuanto a las reseñas, se observó que las reseñas profesionales tienen una relación moderada con las ventas en plataformas como PS3 (correlación de 0.43), sugiriendo que una buena crítica puede influir positivamente en el éxito comercial. Por otro lado, las reseñas de usuarios muestran una relación débil (correlación de 0.13), indicando que, si bien la satisfacción del usuario tiene cierta influencia, no es un factor determinante en las ventas totales. Otros factores, como el marketing y la popularidad del juego, probablemente desempeñan un papel más crucial.
#
# **Perfil del Usuario por Región.**
#
# Las preferencias de plataformas y géneros varían significativamente entre regiones:
#
# **Norteamérica**
#
# Dominada por Xbox 360, PS2 y Wii. Los géneros preferidos son Acción, Deportes y Disparos (Shooter). Las clasificaciones ESRB "Everyone" (Todos) y "Teen" (Adolescentes) lideran las ventas, seguidas por "Mature" (Maduro), lo que indica una amplia diversidad de gustos.
#
# **Europa**
#
# PS2, Xbox 360 y Wii también son las plataformas principales. Los géneros más vendidos son Acción, Deportes y Shooter, similar a Norteamérica. Las clasificaciones "Everyone" y "Teen" son las más populares, con una considerable demanda de juegos "Mature".
#
# **Japón**
#
# Muestra una clara preferencia por plataformas portátiles como Nintendo DS y PSP. Los géneros Role-Playing y Acción son los más populares, a diferencia de otras regiones. Las clasificaciones "Everyone" y "Teen" son las de mayor venta, y la demanda por contenido "Mature" es notablemente menor.
#
# Estas diferencias regionales subrayan la importancia de adaptar las estrategias de desarrollo y marketing según cada mercado para maximizar el éxito comercial.
#
# **Pruebas de Hipótesis.**
#
# **Calificaciones promedio de usuarios para Xbox One y PC**
#
# Se encontró una diferencia estadísticamente significativa en las calificaciones promedio de los usuarios entre Xbox One y PC (p-valor cercano a 0). PC tiende a tener calificaciones ligeramente más altas en promedio (7.06 vs 6.52 para Xbox One).
#
# **Calificaciones promedio de usuarios para géneros Acción y Deportes**
#
# No se encontró una diferencia estadísticamente significativa en las calificaciones promedio de los usuarios entre los géneros Acción y Deportes (p-valor de 0.1148, mayor que el umbral de 0.05). Esto sugiere que, en promedio, los usuarios valoran de manera similar ambos géneros.
#
# **Conclusión**
#
# La industria de los videojuegos es dinámica y está en constante evolución, con ciclos de vida cortos para las plataformas y preferencias regionales marcadas. Para el futuro, es crucial considerar datos del mercado actual, nuevas tecnologías como el streaming y la realidad virtual, y adaptar las estrategias de marketing a las particularidades de cada región para identificar oportunidades rentables y planificar campañas exitosas.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has logrado construir una conclusión general muy completa que sintetiza con claridad los hallazgos clave del proyecto, abordando aspectos técnicos, comerciales y regionales con profundidad y coherencia. El análisis del comportamiento por plataforma, las variaciones regionales y la relación entre reseñas y ventas está muy bien respaldado e interpretado.
#
# </div>
